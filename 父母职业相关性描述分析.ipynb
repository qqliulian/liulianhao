# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mytools2
import seaborn as sns

# %%
data = pd.read_csv('类别变量练习数据1.csv',encoding='GBK')

# %%
print(data.describe())
# Out:
#         父亲工作 父亲职业重新编码  母亲工作 母亲职业重新编码
# count     53       50    52       39
# unique    48        5    42        5
# top     市公安局      公务员  家庭主妇      事业编
# freq       2       17    10       13

# %%
def create_pie_chart(x,y):
    x= data ['父亲职业重新编码'].value_counts().index
y= data['父亲职业重新编码'].value_counts(normalize=True)
fig,ax1= plt.subplots()
labels= data['父亲职业重新编码'].value_counts().index
ax1.pie(y,autopct='%1.1f%%',labels=labels,textprops=dict(color="black"))
plt.show()

# %%
tau_y = mytools2.goodmanKruska_tau_y(data,'父亲职业重新编码','母亲职业重新编码')
tau_y
# Out:
# 0.1819926873857404

# %%
mytools2.相关系数强弱判断(tau_y)
# Out:
# '父母双方职业之间的关系呈现一种极弱相关或无相关的状态'
